# %%
import pandas as pd

# %%
data = pd.read_excel("mock-data.xlsx")
data
# Out:
#    olympic/paralympic sport discipline genre  viability  competitiveness
# 0             olympic    AL         SL     M  42.785810        54.518146
# 1             olympic    AL         GS     M   8.828903        14.325461
# 2             olympic    AL         SG     M  83.488496        72.563035
# 3             olympic    AL         DH     M  84.247847        96.261337
# 4             olympic    AL         AC     M  52.805326        58.288498
# 5             olympic    SB        SBX     M  63.103216         9.500847
# 6             olympic    SB         HP     M  88.911614        60.253876
# 7             olympic    SB        SBS     M   3.308445        55.065757
# 8             olympic    SB        PAR     M  77.070603        45.947063
# 9             olympic    FS         SX     M  32.676877        63.434030
# 10            olympic    FS         HP     M  82.346686         9.921178
# 11            olympic    FS         SS     M   1.180970         8.850662
# ...

# %%
data.to_csv("mock-data.csv")
